# %% [markdown]
# # yfinance Investigation
#
# This file uses the yfinance library to pull stock data for a specific stock

# %%
import yfinance as yf
from datetime import datetime
import matplotlib.pyplot as plt
import pandas as pd
import plotly.graph_objects as go

# %%
clsk = yf.Ticker("CLSK")

# %%
end_date = datetime.now().strftime('%Y-%m-%d')
day_history = clsk.history(start='2022-01-01', end=end_date, interval="1mo")

# %%
day_history
# Out:
#                              Open    High    Low      Close     Volume  \
# Date
# 2022-01-01 00:00:00-05:00   9.730   9.910  5.470   6.720000   38024200
# 2022-02-01 00:00:00-05:00   6.908  11.050  6.170  10.600000   67061100
# 2022-03-01 00:00:00-05:00  11.100  13.910  8.970  12.370000   49969200
# 2022-04-01 00:00:00-04:00  12.370  13.360  6.480   6.490000   30443300
# 2022-05-01 00:00:00-04:00   6.550   7.770  4.530   5.890000   44795400
# 2022-06-01 00:00:00-04:00   5.930   6.100  3.840   3.920000   31364500
# 2022-07-01 00:00:00-04:00   3.900   5.110  3.750   3.990000   36211300
# 2022-08-01 00:00:00-04:00   4.000   6.840  3.840   4.280000   56212700
# 2022-09-01 00:00:00-04:00   4.150   5.000  3.001   3.180000   59361900
# 2022-10-01 00:00:00-04:00   3.240   3.880  2.752   3.480000   59978400
# 2022-11-01 00:00:00-04:00   3.560   3.637  2.010   2.250000   63851800
# 2022-12-01 00:00:00-05:00   2.270   2.505  1.740   2.040000   57605200
# ...

# %%
fig = go.Figure(data=go.Scatter(x=day_history.index,y=day_history['Close'], mode='lines'))
fig.show()

# %%
from plotly.subplots import make_subplots

fig3 = make_subplots(specs=[[{"secondary_y": True}]])
fig3.add_trace(go.Candlestick(x=day_history.index,
                              open=day_history['Open'],
                              high=day_history['High'],
                              low=day_history['Low'],
                              close=day_history['Close'],
                             ))

# %%
clsk.history(period="max", interval="1m", end=end_date)
# Out:
#                                 Open       High        Low      Close  \
# Datetime
# 2024-02-12 09:30:00-05:00  14.190000  14.410000  14.095000  14.389900
# 2024-02-12 09:31:00-05:00  14.390000  14.730000  14.360000  14.727000
# 2024-02-12 09:32:00-05:00  14.720000  14.794000  14.550000  14.781000
# 2024-02-12 09:33:00-05:00  14.785000  14.970000  14.700000  14.910000
# 2024-02-12 09:34:00-05:00  14.900000  15.252800  14.880000  15.179900
# ...                              ...        ...        ...        ...
# 2024-02-16 15:55:00-05:00  17.844999  17.900000  17.844999  17.865000
# 2024-02-16 15:56:00-05:00  17.865000  17.870001  17.850000  17.850000
# 2024-02-16 15:57:00-05:00  17.850000  17.860001  17.850000  17.855000
# 2024-02-16 15:58:00-05:00  17.850000  17.860001  17.830000  17.840000
# 2024-02-16 15:59:00-05:00  17.840000  17.879999  17.840000  17.879999
#
#                             Volume  Dividends  Stock Splits
# Datetime
# ...

# %%
etf = ['AXP','AAPL','BA','CAT','CSCO','CVX','XOM','GS','HD','IBM','INTC','JNJ','KO'] #and any tickers you'd add to be retrived
tit = yf.download(tickers=etf, period='max')
# Out:
# c:\Users\spenc\Documents\Repositories\Lazy-Delphi\python_env\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [                       0%%                      ]c:\Users\spenc\Documents\Repositories\Lazy-Delphi\python_env\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Users\spenc\Documents\Repositories\Lazy-Delphi\python_env\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# ...

# %%
tit
# Out:
# Price        Adj Close                                                 \
# Ticker            AAPL         AXP          BA         CAT       CSCO
# Date
# 1962-01-02         NaN         NaN    0.190931    0.476659        NaN
# 1962-01-03         NaN         NaN    0.194750    0.481301        NaN
# 1962-01-04         NaN         NaN    0.192840    0.493682        NaN
# 1962-01-05         NaN         NaN    0.189022    0.498325        NaN
# 1962-01-08         NaN         NaN    0.189499    0.501420        NaN
# ...                ...         ...         ...         ...        ...
# 2024-02-14  184.149994  210.899994  203.380005  316.709991  50.279999
# 2024-02-15  183.860001  212.529999  205.330002  323.070007  49.060001
# 2024-02-16  182.309998  212.559998  203.889999  321.910004  48.439999
# 2024-02-20  181.559998  212.490005  203.369995  313.739990  48.279999
# 2024-02-21  182.320007  210.889999  201.570007  317.140015  48.480000
#
# ...
